# %%
import sys
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
raw_Data = pd.read_csv('/Users/mattn/Library/CloudStorage/OneDrive-SharedLibraries-UniversityofFlorida/BME 4883 Spring 2024 - '+ 
                       'Team 01 - Intubator Trainers - Raw Data/Intubation Trials/Expert Data Feb 22nd/017-2-2.csv')

x_accel = raw_Data.iloc[:,2]
y_accel = raw_Data.iloc[:,3]
z_accel = raw_Data.iloc[:,4]
time = raw_Data.index.tolist()
# Out:
# 2.41

# %%
fig, ax = plt.subplots()
ax.plot(time, x_accel)
plt.show()

# %%
# Out:
# 2.41

# %%
fig, ax = plt.subplots()
ax.plot(time, y_accel)
plt.show()

# %%
fig, ax = plt.subplots()
ax.plot(time, z_accel)
plt.show()

# %%
max(z_accel)
# Out:
# 102.417
